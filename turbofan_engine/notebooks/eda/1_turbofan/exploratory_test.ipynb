# %%
import pandas as pd
import os
import sys
import matplotlib.pyplot as plt
import seaborn as sns
import util
from class_format_data import FormatData

# %%
format_data = FormatData()
equipment = 'FD001'

# %% [markdown]
# # Análise exploratória dos dados de treino

# %%
format_data.format_raw_data(f"test_{equipment}.txt")

df_test = format_data.get_format_data(f"test_{equipment}.txt")

# %%
df_test
# Out:
#        unit_number   time  setting_1  setting_2  setting_3  sensor_1  \
# 0              1.0    1.0     0.0023     0.0003      100.0    518.67
# 1              1.0    2.0    -0.0027    -0.0003      100.0    518.67
# 2              1.0    3.0     0.0003     0.0001      100.0    518.67
# 3              1.0    4.0     0.0042     0.0000      100.0    518.67
# 4              1.0    5.0     0.0014     0.0000      100.0    518.67
# ...            ...    ...        ...        ...        ...       ...
# 13091        100.0  194.0     0.0049     0.0000      100.0    518.67
# 13092        100.0  195.0    -0.0011    -0.0001      100.0    518.67
# 13093        100.0  196.0    -0.0006    -0.0003      100.0    518.67
# 13094        100.0  197.0    -0.0038     0.0001      100.0    518.67
# 13095        100.0  198.0     0.0013     0.0003      100.0    518.67
#
#        sensor_2  sensor_3  sensor_4  sensor_5  ...  sensor_12  sensor_13  \
# 0        643.02   1585.29   1398.21     14.62  ...     521.72    2388.03
# 1        641.71   1588.45   1395.42     14.62  ...     522.16    2388.06
# 2        642.46   1586.94   1401.34     14.62  ...     521.97    2388.03
# 3        642.44   1584.12   1406.42     14.62  ...     521.38    2388.05
# 4        642.51   1587.19   1401.92     14.62  ...     522.15    2388.03
# ...         ...       ...       ...       ...  ...        ...        ...
# 13091    643.24   1599.45   1415.79     14.62  ...     520.69    2388.00
# 13092    643.22   1595.69   1422.05     14.62  ...     521.05    2388.09
# 13093    643.44   1593.15   1406.82     14.62  ...     521.18    2388.04
# 13094    643.26   1594.99   1419.36     14.62  ...     521.33    2388.08
# 13095    642.95   1601.62   1424.99     14.62  ...     521.07    2388.05
#
#        sensor_14  sensor_15  sensor_16  sensor_17  sensor_18  sensor_19  \
# 0        8125.55     8.4052       0.03      392.0     2388.0      100.0
# 1        8139.62     8.3803       0.03      393.0     2388.0      100.0
# 2        8130.10     8.4441       0.03      393.0     2388.0      100.0
# 3        8132.90     8.3917       0.03      391.0     2388.0      100.0
# 4        8129.54     8.4031       0.03      390.0     2388.0      100.0
# ...          ...        ...        ...        ...        ...        ...
# 13091    8213.28     8.4715       0.03      394.0     2388.0      100.0
# 13092    8210.85     8.4512       0.03      395.0     2388.0      100.0
# 13093    8217.24     8.4569       0.03      395.0     2388.0      100.0
# 13094    8220.48     8.4711       0.03      395.0     2388.0      100.0
# 13095    8214.64     8.4903       0.03      396.0     2388.0      100.0
#
#        sensor_20  sensor_21
# 0          38.86    23.3735
# 1          39.02    23.3916
# 2          39.08    23.4166
# 3          39.00    23.3737
# 4          38.99    23.4130
# ...          ...        ...
# 13091      38.65    23.1974
# 13092      38.57    23.2771
# 13093      38.62    23.2051
# 13094      38.66    23.2699
# 13095      38.70    23.1855
#
# [13096 rows x 26 columns]

# %%
i = 0
for column in df_test.columns:
    fig, ax = plt.subplots(figsize=(25, 6))
    ax.plot(df_test[column])
    ax.set_ylabel(column, fontsize=14)
    ax.set_title(column, fontsize=22)
    i = i + 1
    if i == 6:
        break

# %% [markdown]
# Pode-se observar que há sensores que estão flat, ou seja, estão com valor fixo durante todo tempo. Esses sensores deverão ser removidos. Para identifica-los, será usado a variância. Se um sensor tiver uma variância muito pequena, ele será considerado como flat.

# %%
df_test["sensor_16"].var()
# Out:
# 1.0834183226673213e-34

# %%
good_sensor = list(df_test.columns)
for sensor in df_test.columns:
    if df_test[sensor].var() <= 0.00000001:
        print("Sensor is flat:", sensor)
        good_sensor.remove(sensor)
# Out:
# Sensor is flat: setting_3
# Sensor is flat: sensor_1
# Sensor is flat: sensor_5
# Sensor is flat: sensor_10
# Sensor is flat: sensor_16
# Sensor is flat: sensor_18
# Sensor is flat: sensor_19

# %%
df_test = df_test[good_sensor]
df_test
# Out:
#        unit_number   time  setting_1  setting_2  sensor_2  sensor_3  sensor_4  \
# 0              1.0    1.0     0.0023     0.0003    643.02   1585.29   1398.21
# 1              1.0    2.0    -0.0027    -0.0003    641.71   1588.45   1395.42
# 2              1.0    3.0     0.0003     0.0001    642.46   1586.94   1401.34
# 3              1.0    4.0     0.0042     0.0000    642.44   1584.12   1406.42
# 4              1.0    5.0     0.0014     0.0000    642.51   1587.19   1401.92
# ...            ...    ...        ...        ...       ...       ...       ...
# 13091        100.0  194.0     0.0049     0.0000    643.24   1599.45   1415.79
# 13092        100.0  195.0    -0.0011    -0.0001    643.22   1595.69   1422.05
# 13093        100.0  196.0    -0.0006    -0.0003    643.44   1593.15   1406.82
# 13094        100.0  197.0    -0.0038     0.0001    643.26   1594.99   1419.36
# 13095        100.0  198.0     0.0013     0.0003    642.95   1601.62   1424.99
#
#        sensor_6  sensor_7  sensor_8  sensor_9  sensor_11  sensor_12  \
# 0         21.61    553.90   2388.04   9050.17      47.20     521.72
# 1         21.61    554.85   2388.01   9054.42      47.50     522.16
# 2         21.61    554.11   2388.05   9056.96      47.50     521.97
# 3         21.61    554.07   2388.03   9045.29      47.28     521.38
# 4         21.61    554.16   2388.01   9044.55      47.31     522.15
# ...         ...       ...       ...       ...        ...        ...
# 13091     21.61    553.41   2388.02   9142.37      47.69     520.69
# 13092     21.61    553.22   2388.05   9140.68      47.60     521.05
# 13093     21.61    553.04   2388.11   9146.81      47.57     521.18
# 13094     21.61    553.37   2388.07   9148.85      47.61     521.33
# 13095     21.61    552.48   2388.06   9155.03      47.80     521.07
#
#        sensor_13  sensor_14  sensor_15  sensor_17  sensor_20  sensor_21
# 0        2388.03    8125.55     8.4052      392.0      38.86    23.3735
# 1        2388.06    8139.62     8.3803      393.0      39.02    23.3916
# 2        2388.03    8130.10     8.4441      393.0      39.08    23.4166
# 3        2388.05    8132.90     8.3917      391.0      39.00    23.3737
# 4        2388.03    8129.54     8.4031      390.0      38.99    23.4130
# ...          ...        ...        ...        ...        ...        ...
# 13091    2388.00    8213.28     8.4715      394.0      38.65    23.1974
# 13092    2388.09    8210.85     8.4512      395.0      38.57    23.2771
# 13093    2388.04    8217.24     8.4569      395.0      38.62    23.2051
# 13094    2388.08    8220.48     8.4711      395.0      38.66    23.2699
# 13095    2388.05    8214.64     8.4903      396.0      38.70    23.1855
#
# [13096 rows x 19 columns]

# %%
df_test
# Out:
#        unit_number   time  setting_1  setting_2  sensor_2  sensor_3  sensor_4  \
# 0              1.0    1.0     0.0023     0.0003    643.02   1585.29   1398.21
# 1              1.0    2.0    -0.0027    -0.0003    641.71   1588.45   1395.42
# 2              1.0    3.0     0.0003     0.0001    642.46   1586.94   1401.34
# 3              1.0    4.0     0.0042     0.0000    642.44   1584.12   1406.42
# 4              1.0    5.0     0.0014     0.0000    642.51   1587.19   1401.92
# ...            ...    ...        ...        ...       ...       ...       ...
# 13091        100.0  194.0     0.0049     0.0000    643.24   1599.45   1415.79
# 13092        100.0  195.0    -0.0011    -0.0001    643.22   1595.69   1422.05
# 13093        100.0  196.0    -0.0006    -0.0003    643.44   1593.15   1406.82
# 13094        100.0  197.0    -0.0038     0.0001    643.26   1594.99   1419.36
# 13095        100.0  198.0     0.0013     0.0003    642.95   1601.62   1424.99
#
#        sensor_6  sensor_7  sensor_8  sensor_9  sensor_11  sensor_12  \
# 0         21.61    553.90   2388.04   9050.17      47.20     521.72
# 1         21.61    554.85   2388.01   9054.42      47.50     522.16
# 2         21.61    554.11   2388.05   9056.96      47.50     521.97
# 3         21.61    554.07   2388.03   9045.29      47.28     521.38
# 4         21.61    554.16   2388.01   9044.55      47.31     522.15
# ...         ...       ...       ...       ...        ...        ...
# 13091     21.61    553.41   2388.02   9142.37      47.69     520.69
# 13092     21.61    553.22   2388.05   9140.68      47.60     521.05
# 13093     21.61    553.04   2388.11   9146.81      47.57     521.18
# 13094     21.61    553.37   2388.07   9148.85      47.61     521.33
# 13095     21.61    552.48   2388.06   9155.03      47.80     521.07
#
#        sensor_13  sensor_14  sensor_15  sensor_17  sensor_20  sensor_21
# 0        2388.03    8125.55     8.4052      392.0      38.86    23.3735
# 1        2388.06    8139.62     8.3803      393.0      39.02    23.3916
# 2        2388.03    8130.10     8.4441      393.0      39.08    23.4166
# 3        2388.05    8132.90     8.3917      391.0      39.00    23.3737
# 4        2388.03    8129.54     8.4031      390.0      38.99    23.4130
# ...          ...        ...        ...        ...        ...        ...
# 13091    2388.00    8213.28     8.4715      394.0      38.65    23.1974
# 13092    2388.09    8210.85     8.4512      395.0      38.57    23.2771
# 13093    2388.04    8217.24     8.4569      395.0      38.62    23.2051
# 13094    2388.08    8220.48     8.4711      395.0      38.66    23.2699
# 13095    2388.05    8214.64     8.4903      396.0      38.70    23.1855
#
# [13096 rows x 19 columns]

# %% [markdown]
# ## Criação da feature RUL (Remaining  Useful  Life)

# %%
df_test_rul = pd.DataFrame(df_test.groupby('unit_number')['time'].max()).reset_index()
df_test_rul.columns = ['id', 'max']
df_test_rul
# Out:
#        id    max
# 0     1.0   31.0
# 1     2.0   49.0
# 2     3.0  126.0
# 3     4.0  106.0
# 4     5.0   98.0
# ..    ...    ...
# 95   96.0   97.0
# 96   97.0  134.0
# 97   98.0  121.0
# 98   99.0   97.0
# 99  100.0  198.0
#
# [100 rows x 2 columns]

# %%
df_rul = format_data.read_txt_rul(f'RUL_{equipment}.txt')
df_rul
# Out:
#       max  unit_number
# 0   112.0            1
# 1    98.0            2
# 2    69.0            3
# 3    82.0            4
# 4    91.0            5
# ..    ...          ...
# 95  137.0           96
# 96   82.0           97
# 97   59.0           98
# 98  117.0           99
# 99   20.0          100
#
# [100 rows x 2 columns]

# %%
df_rul['TOTAL_RUL'] = df_test_rul['max'] + df_rul['max']
df_rul
# Out:
#       max  unit_number  TOTAL_RUL
# 0   112.0            1      143.0
# 1    98.0            2      147.0
# 2    69.0            3      195.0
# 3    82.0            4      188.0
# 4    91.0            5      189.0
# ..    ...          ...        ...
# 95  137.0           96      234.0
# 96   82.0           97      216.0
# 97   59.0           98      180.0
# 98  117.0           99      214.0
# 99   20.0          100      218.0
#
# [100 rows x 3 columns]

# %%
df_rul = df_rul.drop(columns=["max"])

# %%
df_test.merge(df_rul, on=['unit_number'], how='left').head(8)
# Out:
#    unit_number  time  setting_1  setting_2  sensor_2  sensor_3  sensor_4  \
# 0          1.0   1.0     0.0023     0.0003    643.02   1585.29   1398.21
# 1          1.0   2.0    -0.0027    -0.0003    641.71   1588.45   1395.42
# 2          1.0   3.0     0.0003     0.0001    642.46   1586.94   1401.34
# 3          1.0   4.0     0.0042     0.0000    642.44   1584.12   1406.42
# 4          1.0   5.0     0.0014     0.0000    642.51   1587.19   1401.92
# 5          1.0   6.0     0.0012     0.0003    642.11   1579.12   1395.13
# 6          1.0   7.0    -0.0000     0.0002    642.11   1583.34   1404.84
# 7          1.0   8.0     0.0006    -0.0000    642.54   1580.89   1400.89
#
#    sensor_6  sensor_7  sensor_8  sensor_9  sensor_11  sensor_12  sensor_13  \
# 0     21.61    553.90   2388.04   9050.17      47.20     521.72    2388.03
# 1     21.61    554.85   2388.01   9054.42      47.50     522.16    2388.06
# 2     21.61    554.11   2388.05   9056.96      47.50     521.97    2388.03
# 3     21.61    554.07   2388.03   9045.29      47.28     521.38    2388.05
# 4     21.61    554.16   2388.01   9044.55      47.31     522.15    2388.03
# 5     21.61    554.22   2388.00   9050.96      47.26     521.92    2388.08
# 6     21.61    553.89   2388.05   9051.39      47.31     522.01    2388.06
# 7     21.61    553.59   2388.05   9052.86      47.21     522.09    2388.06
#
#    sensor_14  sensor_15  sensor_17  sensor_20  sensor_21  TOTAL_RUL
# 0    8125.55     8.4052      392.0      38.86    23.3735      143.0
# 1    8139.62     8.3803      393.0      39.02    23.3916      143.0
# 2    8130.10     8.4441      393.0      39.08    23.4166      143.0
# 3    8132.90     8.3917      391.0      39.00    23.3737      143.0
# 4    8129.54     8.4031      390.0      38.99    23.4130      143.0
# 5    8127.46     8.4238      392.0      38.91    23.3467      143.0
# 6    8134.97     8.3914      391.0      38.85    23.3952      143.0
# 7    8125.93     8.4213      393.0      39.05    23.3224      143.0

# %%
df_test = df_test.merge(df_rul, on=['unit_number'], how='left')
df_test['RUL'] = df_test['TOTAL_RUL'] - df_test['time']
df_test.drop('TOTAL_RUL', axis=1, inplace=True)
df_test
# Out:
#        unit_number   time  setting_1  setting_2  sensor_2  sensor_3  sensor_4  \
# 0              1.0    1.0     0.0023     0.0003    643.02   1585.29   1398.21
# 1              1.0    2.0    -0.0027    -0.0003    641.71   1588.45   1395.42
# 2              1.0    3.0     0.0003     0.0001    642.46   1586.94   1401.34
# 3              1.0    4.0     0.0042     0.0000    642.44   1584.12   1406.42
# 4              1.0    5.0     0.0014     0.0000    642.51   1587.19   1401.92
# ...            ...    ...        ...        ...       ...       ...       ...
# 13091        100.0  194.0     0.0049     0.0000    643.24   1599.45   1415.79
# 13092        100.0  195.0    -0.0011    -0.0001    643.22   1595.69   1422.05
# 13093        100.0  196.0    -0.0006    -0.0003    643.44   1593.15   1406.82
# 13094        100.0  197.0    -0.0038     0.0001    643.26   1594.99   1419.36
# 13095        100.0  198.0     0.0013     0.0003    642.95   1601.62   1424.99
#
#        sensor_6  sensor_7  sensor_8  sensor_9  sensor_11  sensor_12  \
# 0         21.61    553.90   2388.04   9050.17      47.20     521.72
# 1         21.61    554.85   2388.01   9054.42      47.50     522.16
# 2         21.61    554.11   2388.05   9056.96      47.50     521.97
# 3         21.61    554.07   2388.03   9045.29      47.28     521.38
# 4         21.61    554.16   2388.01   9044.55      47.31     522.15
# ...         ...       ...       ...       ...        ...        ...
# 13091     21.61    553.41   2388.02   9142.37      47.69     520.69
# 13092     21.61    553.22   2388.05   9140.68      47.60     521.05
# 13093     21.61    553.04   2388.11   9146.81      47.57     521.18
# 13094     21.61    553.37   2388.07   9148.85      47.61     521.33
# 13095     21.61    552.48   2388.06   9155.03      47.80     521.07
#
#        sensor_13  sensor_14  sensor_15  sensor_17  sensor_20  sensor_21    RUL
# 0        2388.03    8125.55     8.4052      392.0      38.86    23.3735  142.0
# 1        2388.06    8139.62     8.3803      393.0      39.02    23.3916  141.0
# 2        2388.03    8130.10     8.4441      393.0      39.08    23.4166  140.0
# 3        2388.05    8132.90     8.3917      391.0      39.00    23.3737  139.0
# 4        2388.03    8129.54     8.4031      390.0      38.99    23.4130  138.0
# ...          ...        ...        ...        ...        ...        ...    ...
# 13091    2388.00    8213.28     8.4715      394.0      38.65    23.1974   24.0
# 13092    2388.09    8210.85     8.4512      395.0      38.57    23.2771   23.0
# 13093    2388.04    8217.24     8.4569      395.0      38.62    23.2051   22.0
# 13094    2388.08    8220.48     8.4711      395.0      38.66    23.2699   21.0
# 13095    2388.05    8214.64     8.4903      396.0      38.70    23.1855   20.0
#
# [13096 rows x 20 columns]

# %%
fig, ax = plt.subplots(figsize=(25, 6))
ax.plot(df_test.index.values, df_test["RUL"].values)
ax.set_ylabel("RUL", fontsize=14)
ax.set_title("RUL", fontsize=22)
ax.set_xlim(400,800)
ax.set_ylim(0,360)
plt.show()

# %% [markdown]
# Plot de um curto período dos sensores

# %%
i = 0
for column in df_test.columns:
    if ('sensor' in column):
        fig, ax = plt.subplots(figsize=(25, 6))
        ax.plot(df_test.index.values, df_test[column].values)
        ax.set_ylabel(column, fontsize=14)
        ax.set_title(column, fontsize=22)
        ax.set_xlim(400,800)
        plt.show()

# %%
# path onde as imagens serão salvas
path_img = format_data.get_path_img()

# %%
((591 - 357) // 2) + 357
# Out:
# 474

# %%
path_img
# Out:
# WindowsPath('c:/Users/marce/Documentos/MEGAsync/0_PUC-Rio/1_Período/1_Lógica Fuzzy/2_Trabalho final/fuzzy_turbofan/img')

# %%
# [478, 657] = \
# df_test_rul[(df_test_rul.index > 400) & (df_test_rul.index < 800) & (df_test_rul['RUL'] == 0)]
# ((657 - 478) // 2) + 478 = 567

fig, ax = plt.subplots(figsize=(25, 6))

# Plot sensor_2
ax.plot(df_test["sensor_2"], label="Sensor 2", linewidth=2.0)
ax.set_ylabel("sensor_2 (°R)", fontsize=22)
ax.tick_params(axis='y', labelsize=18)

# Create a twin axis for RUL
ax2 = ax.twinx()
ax2.plot(df_test["RUL"], label="RUL", linewidth=2.0, color="#FF6400")
ax2.set_ylabel("RUL", fontsize=22)
ax2.tick_params(axis='y', labelsize=18)

# Set labels and ticks for sensor_2
ax.set_xlabel("Ciclos", fontsize=22)
ax.set_xticklabels(ax.get_xticks(), fontsize=18)  # Ajustar o tamanho das marcas do eixo x

# Set xlim, legend, and plot annotations
ax.set_xlim(-10, 1115)
ax.legend(fontsize=18)

# Calculate y range
y_min, y_max = ax.get_ylim()
y_height = 0.05 * (y_max - y_min)  # 5% of y range
ax.set_ylim(y_min - y_height, y_max + y_height)

# Add annotation
ax.fill_between([357, 591], y_min - y_height, y_max + y_height, color='gray', alpha=0.2)
ax.annotate("Campanha", fontsize=16, color='red', xy=(474, y_max + y_height), xytext=(474, y_max + 2*y_height),
             arrowprops=dict(facecolor='black', arrowstyle='wedge'))
ax.axvline(x=357, color='black', linestyle='--')
ax.axvline(x=591, color='black', linestyle='--')

plt.plot()
plt.savefig(os.path.join(path_img, 'sensor_2_test.svg'), format='svg')
# Out:
# C:\Users\marce\AppData\Local\Temp\ipykernel_24536\580799404.py:20: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticks(), fontsize=18)  # Ajustar o tamanho das marcas do eixo x

# %%
df_test[(df_test["RUL"].index > 350) & (df_test["RUL"].index < 600)]['RUL'].tail(30)
# Out:
# 570    195.0
# 571    194.0
# 572    193.0
# 573    192.0
# 574    191.0
# 575    190.0
# 576    189.0
# 577    188.0
# 578    187.0
# 579    186.0
# 580    185.0
# 581    184.0
# 582    183.0
# 583    182.0
# 584    181.0
# 585    180.0
# 586    179.0
# 587    178.0
# 588    177.0
# 589    176.0
# 590    175.0
# 591    174.0
# 592    173.0
# 593    172.0
# 594    171.0
# 595    170.0
# 596    169.0
# 597    168.0
# 598    167.0
# 599    166.0
# Name: RUL, dtype: float64

# %% [markdown]
# # Box plot dos sensores

# %%
for column in df_test.columns:
    fig, ax = plt.subplots(figsize=(25, 6))
    sns.boxplot(data=df_test, x=column)
    plt.plot()

# %%
df_test.describe()
# Out:
#         unit_number          time     setting_1     setting_2      sensor_2  \
# count  13096.000000  13096.000000  13096.000000  13096.000000  13096.000000
# mean      51.543907     76.836515     -0.000011      0.000004    642.475088
# std       28.289423     53.057749      0.002203      0.000294      0.400899
# min        1.000000      1.000000     -0.008200     -0.000600    641.130000
# 25%       28.000000     33.000000     -0.001500     -0.000200    642.197500
# 50%       52.000000     69.000000     -0.000000     -0.000000    642.460000
# 75%       76.000000    113.000000      0.001500      0.000300    642.740000
# max      100.000000    303.000000      0.007800      0.000700    644.300000
#
#            sensor_3      sensor_4      sensor_6      sensor_7      sensor_8  \
# count  13096.000000  13096.000000  13096.000000  13096.000000  13096.000000
# mean    1588.099204   1404.735362     21.609701    553.757523   2388.070964
# std        5.003274      6.688309      0.001704      0.681286      0.057442
# min     1569.040000   1384.390000     21.600000    550.880000   2387.890000
# 25%     1584.600000   1399.950000     21.610000    553.310000   2388.030000
# 50%     1587.990000   1404.440000     21.610000    553.800000   2388.070000
# 75%     1591.362500   1409.050000     21.610000    554.240000   2388.110000
# max     1607.550000   1433.360000     21.610000    555.840000   2388.300000
#
#            sensor_9     sensor_11     sensor_12     sensor_13     sensor_14  \
# count  13096.000000  13096.000000  13096.000000  13096.000000  13096.000000
# mean    9058.407363     47.416204    521.747724   2388.071025   8138.947817
# std       11.436261      0.195917      0.559627      0.056934     10.188605
# min     9024.530000     46.800000    519.380000   2387.890000   8108.500000
# 25%     9051.020000     47.270000    521.380000   2388.030000   8132.310000
# 50%     9057.320000     47.410000    521.780000   2388.070000   8138.390000
# 75%     9064.110000     47.540000    522.150000   2388.110000   8144.360000
# max     9155.030000     48.260000    523.760000   2388.320000   8220.480000
#
#           sensor_15     sensor_17     sensor_20     sensor_21           RUL
# count  13096.000000  13096.000000  13096.000000  13096.000000  13096.000000
# mean       8.425844    392.571625     38.892502     23.335743    141.238470
# std        0.029009      1.233577      0.141681      0.084120     58.980114
# min        8.332800    389.000000     38.310000     22.935400      7.000000
# 25%        8.405600    392.000000     38.800000     23.281600    102.000000
# 50%        8.424900    393.000000     38.900000     23.339200    140.000000
# 75%        8.444300    393.000000     38.990000     23.393600    179.000000
# max        8.541400    397.000000     39.410000     23.641900    340.000000

# %% [markdown]
# # Conclusões

# %% [markdown]
# Pode observar que a vida restante do turbofan começa com valor elevado e vai descrescendo ao longo do tempo. Porém, nos dados de teste o RUL não chega igual a zero. Isso acontece pois é feito todo um tratamento com os dados de teste para se obter o valor verdadeiro do RUL. O que deverá ser feito no processamento para os dados de treino:
# - **Remoção dos sensores flat**, incluindo o sensor 6.
# - **Cálculo do RUL** (este cálculo é um pouco mais complexo).
